# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
# !conda install -c pytorch torchvision -y
# !conda install matplotlib -y

# %%
training_data = datasets.FashionMNIST(
                root = "data",
                download = True,
                train = True,
                transform = ToTensor()
)
test_data = datasets.FashionMNIST(
                root = "data",
                download = True,
                train = False,
                transform = ToTensor()
)

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
image, label = training_data[0]

# %%
label
# Out:
# 9

# %%
# image  # this is a tensor form
# image.shape
image.squeeze().shape
# Out:
# torch.Size([28, 28])

# %%
plt.figure(figsize=(2,2))
plt.imshow(image.squeeze() , cmap = "gray")
plt.show()

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

labels_map[label]
# Out:
# 'Ankle Boot'

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size= 64, shuffle = True)
teat_dataloader = DataLoader(test_data, batch_size = 64, shuffle = True)

# %%
for image, labels in train_dataloader:
    print(image.size())
    break
# Out:
# torch.Size([64, 1, 28, 28])

# %%
data_iter = iter(train_dataloader)
image, labels = next(data_iter)

# %%
image.size()
# Out:
# torch.Size([64, 1, 28, 28])

# %%
# for seeing first image
plt.figure(figsize= (3,3))
plt.imshow(image[0].squeeze(), cmap= "gray")
plt.show()

# %%
# for knowing ki konsi image hai ye
labels_map[labels[0].item()]
# Out:
# 'T-Shirt'

# %%
#typically when you use pytorch not iter 
for images, label in train_dataloader:
    print(images[0].shape)
    break
# Out:
# torch.Size([1, 28, 28])
